# %% [markdown]
# # Tempe, AZ
# Where is the best place in Tempe to open a healthy meals center which prepare and dilever each meals to the customers.

# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
from bs4 import BeautifulSoup

# %%
import folium # map rendering library

# %%
from geopy.geocoders import Nominatim

# %%
url='https://en.wikipedia.org/wiki/Tempe,_Arizona'
Page= requests.get(url).text

# %%
Bsoup= BeautifulSoup(Page,'lxml')
TargetTabel=Bsoup.find('table')

# %%
table = pd.read_html(Page)
df = pd.DataFrame(table[6])
df.columns=['#','Employers','Employees']
df.head(10)
# Out:
#     #                            Employers  Employees
# 0   1             Arizona State University       8380
# 1   2                           State Farm       6120
# 2   3                                  SRP       2810
# 3   4                          Wells Fargo       2550
# 4   5                       ABM Industries       2000
# 5   6                        City of Tempe       1894
# 6   7                      JP Morgan Chase       1630
# 7   8                            Honeywell       1610
# 8   9                      Express Scripts       1520
# 9  10  Tempe Elementary School District #3       1520

# %%
# Connecting with FOURAQUARE
CLIENT_ID = '3PZZZMHY3A5PZZON2VSR0HVG0WAIHLNXAOMX4GMVUH4STPWA' # your Foursquare ID
CLIENT_SECRET = 'EN0MVBCDLWUUAESRJVW2LCAUMNRSQ1NKLNRCOCNS4RJIIAJ5' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3PZZZMHY3A5PZZON2VSR0HVG0WAIHLNXAOMX4GMVUH4STPWA
# CLIENT_SECRET:EN0MVBCDLWUUAESRJVW2LCAUMNRSQ1NKLNRCOCNS4RJIIAJ5

# %%
#Taking as an example one of the most popular building in the mail campus
address = '650 E Tyler Mall, Tempe, AZ 85281'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.4202784 -111.9328209

# %%
#Search about restaurant within 500 meters
search_query = 'restaurant'
radius = 500
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3PZZZMHY3A5PZZON2VSR0HVG0WAIHLNXAOMX4GMVUH4STPWA&client_secret=EN0MVBCDLWUUAESRJVW2LCAUMNRSQ1NKLNRCOCNS4RJIIAJ5&ll=33.4202784,-111.9328209&v=20180604&query=restaurant&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d2b4fd26adbf5002ca916fa'},
#  'response': {'venues': [{'id': '4f32698e19836c91c7d54d8b',
#     'name': 'Trailer Park Restaurant',
#     'location': {'address': '222 E University Dr',
#      'lat': 33.421963,
#      'lng': -111.936322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.421963,
#        'lng': -111.936322}],
#      'distance': 375,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['222 E University Dr',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1563119570',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d10b941735', 'name': 'F...    False
#
#                          id     location.address location.cc location.city  \
# 0  4f32698e19836c91c7d54d8b  222 E University Dr          US         Tempe
# 1  4bf1d51999d02d7fdd9ec948  202 E University Dr          US         Tempe
# 2  4b5ded34f964a520407429e3  921 E University Dr          US         Tempe
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                375
# 1    United States        at Forest Ave                391
# 2    United States          at Rural Rd                694
#
#                            location.formattedAddress  \
# 0  [222 E University Dr, Tempe, AZ 85281, United ...
# 1  [202 E University Dr (at Forest Ave), Tempe, A...
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                       name          categories              address  cc  \
# 0  Trailer Park Restaurant                Food  222 E University Dr  US
# 1             The Chuckbox        Burger Joint  202 E University Dr  US
# 2            Flaming Kabob  Falafel Restaurant  921 E University Dr  US
#
#     city        country    crossStreet  distance  \
# 0  Tempe  United States            NaN       375
# 1  Tempe  United States  at Forest Ave       391
# 2  Tempe  United States    at Rural Rd       694
#
#                                     formattedAddress  \
# 0  [222 E University Dr, Tempe, AZ 85281, United ...
# 1  [202 E University Dr (at Forest Ave), Tempe, A...
# 2  [921 E University Dr (at Rural Rd), Tempe, AZ ...
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 33.421963, 'lng':...  33.421963 -111.936322
# 1  [{'label': 'display', 'lat': 33.42213894065141...  33.422139 -111.936398
# ...

# %%
dataframe_filtered.name
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='GWC',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Check the area of the second biggest employers in Tempe: State Farm
address = '500 E Rio Salado Pkwy, Tempe, AZ 85281'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.4294581489057 -111.932506345303

# %%
#Search about restaurant within 1000 meters
search_query = 'restaurant'
radius = 1000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=3PZZZMHY3A5PZZON2VSR0HVG0WAIHLNXAOMX4GMVUH4STPWA&client_secret=EN0MVBCDLWUUAESRJVW2LCAUMNRSQ1NKLNRCOCNS4RJIIAJ5&ll=33.4294581489057,-111.932506345303&v=20180604&query=restaurant&radius=1000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d2b518abf7dde002c7fb01c'},
#  'response': {'venues': [{'id': '4a42d5e9f964a5204aa61fe3',
#     'name': 'Rúla Búla Irish Pub and Restaurant',
#     'location': {'address': '401 S Mill Ave',
#      'crossStreet': 'at 4th St',
#      'lat': 33.42645457538413,
#      'lng': -111.93986232122089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.42645457538413,
#        'lng': -111.93986232122089}],
#      'distance': 760,
#      'postalCode': '85281',
#      'cc': 'US',
#      'city': 'Tempe',
#      'state': 'AZ',
#      'country': 'United States',
#      'formattedAddress': ['401 S Mill Ave (at 4th St)',
#       'Tempe, AZ 85281',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'shortName': 'Irish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...    False
# 2  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 4  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...    False
#
#                          id     location.address location.cc location.city  \
# 0  4a42d5e9f964a5204aa61fe3       401 S Mill Ave          US         Tempe
# 1  4ade0de7f964a520b56d21e3    423 S Mill Avenue          US         Tempe
# 2  4cec1036b99754815ce90f45       423 S Mill Ave          US         Tempe
# 3  4ceec65ab80da0930c3e2900       101 N Mill Ave          US         Tempe
# 4  4f32698e19836c91c7d54d8b  222 E University Dr          US         Tempe
#
#   location.country location.crossStreet  location.distance  \
# 0    United States            at 4th St                760
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                  name          categories  \
# 0  Rúla Búla Irish Pub and Restaurant           Irish Pub
# 1                   Restaurant Mexico  Mexican Restaurant
# 2                   Restaurant Mexixo  Mexican Restaurant
# 3              Boxty House Restaurant                Café
# 4             Trailer Park Restaurant                Food
# 5                        The Chuckbox        Burger Joint
# 6       Islands Fine Burgers & Drinks                Food
# 7                       Flaming Kabob  Falafel Restaurant
# 8                      Gordon Biersch             Brewery
#
#                address  cc   city        country    crossStreet  distance  \
# 0       401 S Mill Ave  US  Tempe  United States      at 4th St       760
# 1    423 S Mill Avenue  US  Tempe  United States         3rd St       774
# 2       423 S Mill Ave  US  Tempe  United States     5th Street      1190
# 3       101 N Mill Ave  US  Tempe  United States         Fourth       731
# ...

# %%
dataframe_filtered.name
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='GWC',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
